# %% [markdown]
# # Notebook useful for several papers, i.e. Quintom, Horndeski

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from getdist import plots
import planckStyle
import pylab
import numpy as np

params1 = {'backend': 'pdf',
               'axes.labelsize': 10,
               'xtick.labelsize': 10,
               'ytick.labelsize': 10,
               'legend.fontsize': 16,
               'lines.markersize': 6,
               'font.size': 25,
               'text.usetex': True}#
pylab.rcParams.update(params1)

# %%
dir_name = '/Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains/'

# %% [markdown]
# ## Quintess

# %%
#roots = ['Quintom_all_phy_BBAO+Planck_15', 'Quintom_all_phy_BBAO+Planck_15+HD']
#roots = ['Quintom_coupling_phy_BBAO','Quintom_coupling_phy_BBAO+HD', 'Quintom_coupling_phy_BBAO+Planck_15', 'Quintom_coupling_phy_BBAO+Planck_15+HD'] #, 'Quintom_phy_BBAO+Planck_15',  'Quintom_phy_BBAO+Planck_15+HD'] 
#roots = ['Quintom_phy_BBAO', 'Quintom_phy_BBAO+HD', 'Quintom_phy_BBAO+Planck_15',  'Quintom_phy_BBAO+Planck_15+HD'] 
#roots = ['Phantom_phy_BBAO', 'Phantom_phy_BBAO+HD',  'Phantom_phy_BBAO+Planck_15+HD'] 
#roots = ['Quintess_phy_BBAO', 'Quintess_phy_BBAO+HD',  'Quintess_phy_BBAO+Planck_15+HD']

# %%
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_2D': 0.8, 'smooth_scale_1D': 0.8, 'ignore_rows': 0.1})
#g.plots_2d(roots, param_pairs=[['mquin','h']], nx=1, filled=True, legend_labels=False, lims=[0.0, 2., None, None])
#            line_args={'lw':2,  'ls':'-'},  
#           colors = ['blue','red','green'], alphas=[.9,0.7,0.5])
#g.add_legend(['BAO+HD', 'BBAO+PLK+HD', 'BAO','BAO+PLK'], 
#             colored_text=True,  legend_loc='lower left')  
#g.export('Quintess_2d.pdf')
#g.plot_1d(roots, param='mquin')
g.triangle_plot(roots, ['Om','h', 'mquin'],  
                analysis_settings={'smooth_scale_1D': .1, 'ignore_rows': 0.}, # plot_3d_with_param='beta',
                  width_inch=10, line_args={'lw':2,  'ls':'-'}, 
               legend_labels=['BAO', 'BAO+HD', 'BAO+PLK', 'BBAO+PLK+HD'])
#g.add_legend(['BAO+HD', 'BBAO+PLK+HD', 'BAO','BAO+PLK'], legend_loc='upper left')
#g.export('Quintom_coupling.pdf')

# %%
roots = ['Phantom_phy_BBAO', 'Phantom_phy_BBAO+HD',  'Phantom_phy_BBAO+Planck_15+HD']  

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=7, 
                            analysis_settings={'smooth_scale_2D': 0.8, 'smooth_scale_1D': 0.8, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mphan'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['BAO', 'BAO+HD', 'BAO+HD+PLK'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')
g.subplots[1,0].grid(True)
g.subplots[1,0].set_ylim(0, 1.8)

g.subplots[1,1].set_xlim(0, 1.8)

g.subplots[0,0].set_title('Phantom', fontsize=20)
g.export('Phantom.pdf')

# %%
roots = ['Quintess_phy_BBAO', 'Quintess_phy_BBAO+HD',  'Quintess_phy_BBAO+Planck_15+HD'] 

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=7, 
                            analysis_settings={'smooth_scale_2D': 0.8, 'smooth_scale_1D': 0.8, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['BAO', 'BAO+HD', 'BAO+HD+PLK'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')
g.subplots[1,0].grid(True)
g.subplots[1,0].set_ylim(0, 2.1)

g.subplots[1,1].set_xlim(0, 2.1)

g.subplots[0,0].set_title('Quintessence', fontsize=20)
g.export('Quintess.pdf')

# %%
roots = ['Quintom_phy_BBAO', 'Quintom_phy_BBAO+HD',  'Quintom_phy_BBAO+Planck_15+HD']

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=8, 
                            analysis_settings={'smooth_scale_2D': 0.8, 'smooth_scale_1D': 0.8, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['BAO', 'BAO+HD', 'BAO+HD+PLK'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')

g.subplots[1,0].set_ylim(0, 2.6)
g.subplots[2,0].set_ylim(0, 2.)
g.subplots[1,1].set_xlim(0, 2.6)
g.subplots[2,1].set_xlim(0, 2.6)
g.subplots[2,1].set_ylim(0, 2.)
g.subplots[2,2].set_xlim(0, 2.)

g.subplots[1,0].grid(True)
g.subplots[2,0].grid(True)
g.subplots[2,1].grid(True)

g.subplots[0,0].set_title('Quintom', fontsize=20)
g.export('Quintom.pdf')

# %%
roots = ['Quintom_coupling_phy_BBAO','Quintom_coupling_phy_BBAO+HD', 'Quintom_coupling_phy_BBAO+Planck_15+HD'] 


g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=9, 
                            analysis_settings={'smooth_scale_2D': 0.9, 'smooth_scale_1D': 0.9, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan', 'beta'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['BAO', 'BAO+HD', 'BAO+HD+PLK'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')
g.subplots[1,0].set_ylim(0, 2.6)
g.subplots[1,1].set_xlim(0, 2.8)
g.subplots[2,0].set_ylim(0, 2.)
g.subplots[2,1].set_xlim(0, 2.8)
g.subplots[2,1].set_ylim(0, 2.)
g.subplots[2,2].set_xlim(0, 2.)
g.subplots[3,0].set_ylim(0, 10.)
g.subplots[3,1].set_xlim(0, 2.8)
g.subplots[3,1].set_ylim(0, 10)
g.subplots[3,2].set_xlim(0, 2.)
g.subplots[3,2].set_ylim(0, 10.)
g.subplots[3,3].set_xlim(0, 10.)

g.subplots[1,0].grid(True)
g.subplots[2,0].grid(True)
g.subplots[2,1].grid(True)
g.subplots[3,0].grid(True)
g.subplots[3,1].grid(True)
g.subplots[3,2].grid(True)

g.subplots[0,0].set_title('Quintom + $\\beta$', fontsize=20)
g.export('Quintom_coupling.pdf')

# %%
roots = ['Quintom_cos_beta_delta_phy_BBAO+Planck_15+HD+SN'] 


g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=9, 
                            analysis_settings={'smooth_scale_2D': 0.9, 'smooth_scale_1D': 0.9, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan', 'beta', 'delta'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['BAO', 'BAO+HD', 'BAO+HD+PLK'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')
# Out:
# /Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains/Quintom_cos_beta_delta_phy_BBAO+Planck_15+HD+SN_1.txt
# /Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains/Quintom_cos_beta_delta_phy_BBAO+Planck_15+HD+SN_2.txt
# /Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains/Quintom_cos_beta_delta_phy_BBAO+Planck_15+HD+SN_3.txt
# /Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains/Quintom_cos_beta_delta_phy_BBAO+Planck_15+HD+SN_4.txt
# WARNING:root:outlier fraction 0.000971345313259
# /Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains/Quintom_cos_beta_delta_phy_BBAO+Planck_15+HD+SN_5.txt
# /Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains/Quintom_cos_beta_delta_phy_BBAO+Planck_15+HD+SN_6.txt
# Removed 0.1 as burn in

# %%
samples = g.sampleAnalyser.samplesForRoot('LCDM_phy_Planck_15+BBAO+SN+HD')
for i,j,k in zip(samples.paramNames.list(), samples.means, samples.sddev):
    print i,'\t \t',j,k
# Out:
# /Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains/LCDM_phy_Planck_15+BBAO+SN+HD_1.txt
# /Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains/LCDM_phy_Planck_15+BBAO+SN+HD_2.txt
# /Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains/LCDM_phy_Planck_15+BBAO+SN+HD_3.txt
# /Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains/LCDM_phy_Planck_15+BBAO+SN+HD_4.txt
# Removed 0.1 as burn in
# Om 	 	0.30180837559377754 0.006401707399068217
# Obh2 	 	0.022445091184305675 0.00014764228814432862
# h 	 	0.6819351173757116 0.004939914833140761
# SPlanck_15_like 	 	-1.2895590004569715 1.0628171038817933
# DR11LOWZ_like 	 	-0.18031207551486747 0.18115903345394876
# DR11CMASS_like 	 	-1.474868594010671 0.3338790337295568
# DR11LyaAuto_like 	 	-2.1410607092163567 0.07953460442837147
# DR11LyaCross_like 	 	-2.174932498230426 0.11979316670309409
# SixdFGS_like 	 	-0.010070026972305197 0.013935075187414317
# MGS_like 	 	-0.9633322844580309 0.26902743396903406
# BetouleSN_like 	 	-16.635592122665596 0.03713039716829319
# HD_like 	 	-13.343164566333462 0.3626552793156494

# %%
print samples.likeStats
# Out:
# Best fit sample -log(Like) = 36.722400
# Ln(mean 1/like) = 41.126511
# mean(-Ln(like)) = 38.212892
# -Ln(mean like)  = 37.769513
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0165500E-01  2.9026500E-01  3.1377900E-01  2.8458300E-01  3.1971600E-01   \Omega_m*
# Obh2                2.2449000E-02  2.2172800E-02  2.2717100E-02  2.2039800E-02  2.2849900E-02   \Omega_bh^2
# h                   6.8199300E-01  6.7289000E-01  6.9104400E-01  6.6847400E-01  6.9549400E-01   h
# SPlanck_15_like    -8.0172100E-02 -1.9587600E+00 -2.0355700E-04 -4.1385700E+00 -2.0355700E-04   SPlanck_15
# DR11LOWZ_like      -1.2418200E-01 -6.1755300E-01 -2.4627200E-11 -9.8758100E-01 -2.4627200E-11   DR11LOWZ
# DR11CMASS_like     -1.3125300E+00 -2.2990000E+00 -1.2129600E+00 -3.2247500E+00 -1.2067900E+00   DR11CMASS
# DR11LyaAuto_like   -2.1393800E+00 -2.2864100E+00 -1.9936500E+00 -2.3631300E+00 -1.9212500E+00   DR11LyaAuto
# DR11LyaCross_like  -2.1745500E+00 -2.3937800E+00 -1.9535700E+00 -2.4955100E+00 -1.8450300E+00   DR11LyaCross
# SixdFGS_like       -1.3577200E-03 -4.4232100E-02 -3.5411100E-11 -8.6535300E-02 -9.1864400E-13   SixdFGS
# MGS_like           -9.5275500E-01 -1.4847000E+00 -5.0147900E-01 -1.7763500E+00 -3.2897500E-01   MGS
# BetouleSN_like     -1.6617400E+01 -1.6730200E+01 -1.6607200E+01 -1.6829500E+01 -1.6607200E+01   BetouleSN
# HD_like            -1.3320100E+01 -1.4060800E+01 -1.2726500E+01 -1.4452900E+01 -1.2462600E+01   HD

# %%
# %pwd
# Out:
# u'/Users/josevazquezgonzalez/Desktop/Desktop_Jose/work/Papers/SuperGravity/getdist'

# %%
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_2D': -1., 'ignore_rows': 0.1})

roots0 = ['LCDM_phy_BBAO', 'LCDM_phy_BBAO+HD',  'LCDM_phy_BBAO+Planck_15+HD']
roots1 = ['Quintess_phy_BBAO', 'Quintess_phy_BBAO+HD',  'Quintess_phy_BBAO+Planck_15+HD'] 
roots2 = ['Phantom_phy_BBAO', 'Phantom_phy_BBAO+HD',  'Phantom_phy_BBAO+Planck_15+HD']  
roots3 = ['Quintom_phy_BBAO', 'Quintom_phy_BBAO+HD',  'Quintom_phy_BBAO+Planck_15+HD']
roots4 = ['Quintom_coupling_phy_BBAO','Quintom_coupling_phy_BBAO+HD', 'Quintom_coupling_phy_BBAO+Planck_15+HD'] 


for a in roots0:
    f= open(a+".txt","w+") 
    samples = g.sampleAnalyser.samplesForRoot(a)
    for i,j,k in zip(samples.paramNames.list(), samples.means, samples.sddev):
        if ('like' not in i) and ('prior' not in i) and ('Obh2' not in i): f.write(('%s,%f,%f \n')%(i.strip(),j,k))
    f.close()
    
    h= open(a+".stats","w+")
    h.write('{}'.format(samples.likeStats))
    print '{}'.format(samples.likeStats)
    h.close()

#p = samples.getParams()
#print 'mean, err = ', samples.mean(p.Om), samples.std(p.Om)
#print '95% limits: ',samples.twoTailLimits(p.Om, 0.95)
# Out:
# /Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains/LCDM_phy_BBAO_1.txt
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-22-55b0717355a2> in <module>()
#      11 for a in roots0:
#      12     f= open(a+".txt","w+")
# ---> 13     samples = g.sampleAnalyser.samplesForRoot(a)
#      14     for i,j,k in zip(samples.paramNames.list(), samples.means, samples.sddev):
#      15         if ('like' not in i) and ('prior' not in i) and ('Obh2' not in i): f.write(('%s,%f,%f \n')%(i.strip(),j,k))
#
# /Users/josevazquezgonzalez/Desktop/Desktop_Jose/work/Papers/2019/SuperGravity/getdist/getdist/plots.pyc in samplesForRoot(self, root, file_root, cache)
#     462             raise GetDistPlotError('chain not found: ' + root)
#     463
# --> 464         self.mcsamples[root] = loadMCSamples(file_root, self.ini, jobItem, settings=dist_settings)
#     465         return self.mcsamples[root]
#     466
#
# /Users/josevazquezgonzalez/Desktop/Desktop_Jose/work/Papers/2019/SuperGravity/getdist/getdist/mcsamples.pyc in loadMCSamples(file_root, ini, jobItem, no_cache, settings, dist_settings)
#      85     if not len(files):
#      86         raise IOError('No chains found: ' + file_root)
# ---> 87     samples.readChains(files)
#      88     samples.savePickle(cachefile)
#      89     return samples
#
# /Users/josevazquezgonzalez/Desktop/Desktop_Jose/work/Papers/2019/SuperGravity/getdist/getdist/mcsamples.pyc in readChains(self, chain_files)
#     364         :return: self.
#     365         """
# --> 366         self.loadChains(self.root, chain_files)
#     367
#     368         if self.ignore_frac and (not self.jobItem or
#
# /Users/josevazquezgonzalez/Desktop/Desktop_Jose/work/Papers/2019/SuperGravity/getdist/getdist/chains.pyc in loadChains(self, root, files, ignore_lines)
#     923         for fname in files:
#     924             if print_load_details: print(fname)
# --> 925             self.chains.append(WeightedSamples(fname, ignore_lines or self.ignore_lines))
#     926         if len(self.chains) == 0:
#     927             raise WeightedSampleError('loadChains - no chains found for ' + root)
#
# /Users/josevazquezgonzalez/Desktop/Desktop_Jose/work/Papers/2019/SuperGravity/getdist/getdist/chains.pyc in __init__(self, filename, ignore_rows, samples, weights, loglikes, name_tag, files_are_chains)
#     158
#     159         if filename:
# --> 160             cols = loadNumpyTxt(filename, skiprows=ignore_rows)
#     161             self.setColData(cols, are_chains=files_are_chains)
#     162             self.name_tag = name_tag or os.path.basename(filename)
#
# /Users/josevazquezgonzalez/Desktop/Desktop_Jose/work/Papers/2019/SuperGravity/getdist/getdist/chains.pyc in loadNumpyTxt(fname, skiprows)
#      75         return pandas.read_csv(fname, delim_whitespace=True, header=None, dtype=np.float64, skiprows=skiprows).values
#      76     else:
# ---> 77         return np.loadtxt(fname, skiprows=skiprows)
#      78
#      79
#
# /Library/Python/2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#    1099         # converting the data
#    1100         X = None
# -> 1101         for x in read_data(_loadtxt_chunksize):
#    1102             if X is None:
#    1103                 X = np.array(x, dtype)
#
# /Library/Python/2.7/site-packages/numpy/lib/npyio.pyc in read_data(chunk_size)
#    1026
#    1027             # Convert each value according to its column and store
# -> 1028             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1029
#    1030             # Then pack it according to the dtype's nesting
#
# /Library/Python/2.7/site-packages/numpy/lib/npyio.pyc in floatconv(x)
#     744         if '0x' in x:
#     745             return float.fromhex(x)
# --> 746         return float(x)
#     747
#     748     typ = dtype.type
#
# UnicodeEncodeError: 'decimal' codec can't encode characters in position 0-45660: invalid decimal Unicode string

# %%
'{}'.format(samples.likeStats)
# Out:
# 'Best fit sample -log(Like) = 19.043000\nmean(-Ln(like)) = 21.522092\n-Ln(mean like)  = 20.800690\n\nparameter           bestfit        lower1         upper1         lower2         upper2\nOm                  3.3931600E-01  2.5830200E-01  3.9123500E-01  2.4171500E-01  4.1415800E-01   \\Omega_m*\nObh2                2.2446200E-02  2.2052000E-02  2.2819100E-02  2.1914200E-02  2.2971700E-02   \\Omega_bh^2\nh                   6.4187300E-01  5.9516800E-01  7.3759500E-01  5.8026900E-01  7.6122300E-01   h\nmquin               1.8639500E-01  2.9108000E-05  2.2470100E+00  2.2762700E-05  2.7304600E+00   m_{\\phi}\nmphan               9.1505600E-01  1.8540800E-05  1.4789100E+00  1.8540800E-05  1.6708000E+00   m_{\\psi}\nbeta                2.3481400E+00 -1.7629000E-01  8.3483800E+00 -2.7447600E-01  8.3483800E+00   \\beta\nDR11LOWZ_like      -3.2928600E-01 -1.7367300E+00 -2.9743400E-09 -2.6128300E+00 -2.6778700E-10   DR11LOWZ\nDR11CMASS_like     -7.7412300E-01 -3.3538100E+00 -1.2279100E-01 -4.9863400E+00 -3.9136800E-02   DR11CMASS\nDR11LyaAuto_like   -2.1343000E+00 -2.6453100E+00 -1.8663500E+00 -2.9219000E+00 -1.7806800E+00   DR11LyaAuto\nDR11LyaCross_like  -2.0084600E+00 -2.3083700E+00 -1.7225000E+00 -2.4205700E+00 -1.6468400E+00   DR11LyaCross\nSixdFGS_like       -1.7099200E-01 -9.8917900E-01 -3.0143400E-11 -1.5196100E+00 -1.9859600E-11   SixdFGS\nMGS_like           -2.3319200E-01 -2.0264100E+00 -4.8390700E-06 -2.7848400E+00 -6.3310100E-08   MGS\nSPlanck_15_like    -6.8800700E-02 -3.2378600E+00 -2.1678100E-03 -5.8179100E+00 -2.1678100E-03   SPlanck_15\nHD_like            -1.3323800E+01 -1.4635100E+01 -1.2471200E+01 -1.5313100E+01 -1.2274600E+01   HD\n'

# %%
for i,j,k in zip(samples.paramNames.list(), samples.means, samples.sddev):
    print i,'\t \t',j,k
# Out:
# Om 	 	0.3185965207286606 0.01619735803624028
# Obh2 	 	0.022453869982207088 0.0001613630780497297
# h 	 	0.6625411966759034 0.0172967753887341
# mquin 	 	0.6467202643156497 0.2742016243540375
# DR11LOWZ_like 	 	-0.33442324546792485 0.34402381337231336
# DR11CMASS_like 	 	-1.150903904015453 0.5469640753367384
# DR11LyaAuto_like 	 	-2.2625577762567777 0.11393217116755114
# DR11LyaCross_like 	 	-2.0519895259064396 0.12065981854549525
# SixdFGS_like 	 	-0.10432222144950162 0.1347583628907883
# MGS_like 	 	-0.5786760620740913 0.3857505159975442
# SPlanck_15_like 	 	-1.4552291364246845 1.1907320755160906
# HD_like 	 	-13.447007831210867 0.39918993727791047

# %%
# %pwd
# Out:
# u'/Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/getdist'

# %% [markdown]
# ## Quintess

# %%
roots = ['Quintess_phy_HD', 'Quintess_phy_BBAO']

# %%
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_1D': -1., 'ignore_rows': 0.2})
g.plots_1d(roots, params=['mquin'], nx=2,legend_labels=False, colors = ['blue','red','green'], xlims=[[0.0,1.5]])
g.add_legend(['$w_i$'], legend_loc='upper right')

# BAO si se ve el pico

# %%
samples = g.sampleAnalyser.samplesForRoot('Quintess_phy_Planck_15+BBAO')

p = samples.getParams()
print 'mean, err = ', samples.mean(p.mquin), samples.std(p.mquin)
print '95% limits: ',samples.twoTailLimits(p.mquin, 0.95)
print samples.likeStats
# Out:
# mean, err =  0.608699706155 0.268495555676
# 95% limits:  [ 0.0819374  1.07184  ]
# Best fit sample -log(Like) = 6.062090
# Ln(mean 1/like) = 10.984475
# mean(-Ln(like)) = 7.931078
# -Ln(mean like)  = 7.413478
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.2561800E-01  2.9077200E-01  3.6377200E-01  2.8364100E-01  3.7720100E-01   \Omega_m*
# Obh2                2.2414100E-02  2.2093400E-02  2.2773200E-02  2.1943900E-02  2.2901900E-02   \Omega_bh^2
# h                   6.5528400E-01  6.1797700E-01  6.9345600E-01  6.0890000E-01  6.9955000E-01   h
# mquin               8.0558500E-01  1.4134000E-02  1.1872000E+00  1.4134000E-02  1.2615000E+00   m_{\phi}
# SPlanck_15_like    -5.8865100E-02 -2.4401900E+00 -7.2701600E-04 -4.6247900E+00 -7.2701600E-04   SPlanck_15
# DR11LOWZ_like      -3.8552400E-01 -1.7797000E+00 -5.9444400E-12 -2.5522300E+00 -5.9444400E-12   DR11LOWZ
# DR11CMASS_like     -7.2916800E-01 -2.4654200E+00 -2.3949900E-01 -3.7206700E+00 -1.6301900E-01   DR11CMASS
# DR11LyaAuto_like   -2.3678900E+00 -2.6510300E+00 -2.1037900E+00 -2.7566800E+00 -2.0145600E+00   DR11LyaAuto
# DR11LyaCross_like  -2.0752700E+00 -2.3320800E+00 -1.8422400E+00 -2.4335400E+00 -1.7531200E+00   DR11LyaCross
# SixdFGS_like       -1.1983100E-01 -7.0451700E-01 -1.6853300E-09 -9.9053900E-01 -1.8949800E-10   SixdFGS
# MGS_like           -3.2554500E-01 -1.4884500E+00 -5.7197200E-06 -1.8759900E+00 -2.8797600E-07   MGS

# %%
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_2D': -1., 'ignore_rows': 0.2})
g.plots_2d(roots, param_pairs=[['mquin','Om'], ['mquin','h']], nx=2, filled=True, 
           lims=[0.0, 1.5, None, None],
            line_args={'lw':2,  'ls':'-'},  
           colors = ['blue','red','green'], alphas=[.9,0.7,0.5], legend_labels=False)
g.add_legend(['Planck+BBAO','Planck+SN'], 
             colored_text=True,  legend_loc='lower left')  
g.export('Quintess_2d.pdf')

# %%
g.triangle_plot(['Quintess_phy_Planck_15+BBAO'], ['Om','h', 'mquin'],  
                analysis_settings={'smooth_scale_1D': .1, 'ignore_rows': 0.},
                plot_3d_with_param='h',  width_inch=10, 
               legend_labels=['Simulation'])
g.add_legend(['Planck+BBAO'],  legend_loc='best') 
g.export('Quintess_3d.pdf')

# %% [markdown]
# ## Phantom

# %%
roots = ['Phantom_phy_Planck_15+BBAO', 'Phantom_phy_Planck_15+SN']

# %%
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_1D': -1., 'ignore_rows': 0.2})
g.plots_1d(roots, params=['mphan'], nx=2,legend_labels=False, 
                            colors = ['blue', 'red','green'], xlims=[[0.0,1.5]])
g.add_legend(['$w_i$'], legend_loc='upper right')

# El pico tal vez con HD

# %%
samples = g.sampleAnalyser.samplesForRoot('Phantom_phy_Planck_15+BBAO')

p = samples.getParams()
print 'mean, err = ', samples.mean(p.mphan), samples.std(p.mphan)
print '95% limits: ',samples.twoTailLimits(p.mphan, 0.95)
print samples.likeStats
# Out:
# mean, err =  0.308745607026 0.213452011967
# 95% limits:  [ 0.030274  0.787159]
# Best fit sample -log(Like) = 7.171690
# Ln(mean 1/like) = 12.628576
# mean(-Ln(like)) = 9.230147
# -Ln(mean like)  = 8.608218
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0132400E-01  2.7613000E-01  3.1428300E-01  2.6186000E-01  3.2035400E-01   \Omega_m*
# Obh2                2.2309600E-02  2.2003700E-02  2.2648900E-02  2.1870700E-02  2.2769300E-02   \Omega_bh^2
# h                   6.8478900E-01  6.7451100E-01  7.1559000E-01  6.7048600E-01  7.3600300E-01   h
# mphan               3.9527800E-02  1.4052800E-02  7.5619700E-01  1.4052800E-02  9.9209200E-01   m_{\psi}
# SPlanck_15_like    -2.6804300E-01 -2.8077200E+00 -5.2351700E-03 -5.1633600E+00 -4.3776700E-04   SPlanck_15
# DR11LOWZ_like      -6.8655200E-02 -5.3810400E-01 -2.2404400E-10 -8.9500600E-01 -9.5431900E-11   DR11LOWZ
# DR11CMASS_like     -1.4188200E+00 -3.3702300E+00 -1.1806200E+00 -4.6230500E+00 -1.1734800E+00   DR11CMASS
# DR11LyaAuto_like   -2.2313500E+00 -2.3968700E+00 -2.0267300E+00 -2.4738900E+00 -1.9263400E+00   DR11LyaAuto
# DR11LyaCross_like  -2.1353300E+00 -2.3758000E+00 -1.8450200E+00 -2.4812700E+00 -1.7566500E+00   DR11LyaCross
# SixdFGS_like       -3.0367600E-05 -1.2398000E-01 -5.2026100E-10 -3.1515500E-01 -1.5256900E-11   SixdFGS
# MGS_like           -1.0494600E+00 -2.1390100E+00 -5.4220900E-01 -2.7967300E+00 -3.6481700E-01   MGS

# %%
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_2D': -1., 'ignore_rows': 0.2})
g.plots_2d(roots, param_pairs=[['mphan','Om'], ['mphan','h']], nx=2, filled=True, 
           lims=[0.0, 1.1, None, None],
           legend_labels=False, line_args={'lw':2,  'ls':'-'},  
           colors = ['blue','red','green'], alphas=[0.8,0.8,0.8])
g.add_legend(['Planck+BBAO','Planck+SN'], 
             colored_text=True,  legend_loc='upper left')  
g.export('Phantom_2d.pdf')

# %%
g.triangle_plot(['Phantom_phy_Planck_15+BBAO'], ['Om','h', 'mphan'], 
                plot_3d_with_param='h', 
                legend_labels=['Simulation'])
g.add_legend(['Planck+BBAO'],  legend_loc='best') 
g.export('Phantom_3d.pdf')

# %% [markdown]
# ## Quintom

# %%
roots = ['Quintom_phy_Planck_15+BBAO+HD', 'Quintom_phy_Planck_15+BBAO+SN']

# %%
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_1D ': -1., 'ignore_rows': 0.2})
g.plots_1d(roots, params=['mquin', 'mphan'], nx=2,legend_labels=False, colors = ['blue','red','green','orange'],
           xlims=[[0.0,3], [0.0,3]])
g.add_legend(['$w_i$'], legend_loc='upper right')

#el pico se con BAO phi, psi

# %%
samples = g.sampleAnalyser.samplesForRoot('Quintom_phy_Planck_15+BBAO')

p = samples.getParams()
print 'mean, err = ', samples.mean(p.Om), samples.std(p.Om)
print '95% limits: ',samples.twoTailLimits(p.Om, 0.95)
print samples.likeStats
# Out:
# mean, err =  0.306230761019 0.0178871013829
# 95% limits:  [ 0.272477  0.346017]
# Best fit sample -log(Like) = 6.076820
# Ln(mean 1/like) = 11.113911
# mean(-Ln(like)) = 8.241761
# -Ln(mean like)  = 7.710279
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.2877000E-01  2.6138500E-01  3.6312800E-01  2.5352100E-01  3.6757600E-01   \Omega_m*
# Obh2                2.2475700E-02  2.2075100E-02  2.2783900E-02  2.1938300E-02  2.2935300E-02   \Omega_bh^2
# h                   6.5154800E-01  6.2039500E-01  7.2722300E-01  6.1784600E-01  7.3485700E-01   h
# mquin               9.7047900E-01  1.3929000E-04  2.1920500E+00  1.9474600E-05  2.2203400E+00   m_{\phi}
# mphan               5.2255200E-02  1.0067700E-02  2.9997900E+00  6.3524100E-03  2.9998000E+00   m_{\psi}
# SPlanck_15_like    -1.2556600E-01 -2.7242600E+00 -6.1485700E-04 -4.8523500E+00 -6.1485700E-04   SPlanck_15
# DR11LOWZ_like      -4.3304600E-01 -2.0378500E+00 -1.7705100E-09 -2.7837700E+00 -3.6328900E-10   DR11LOWZ
# DR11CMASS_like     -6.6250600E-01 -2.6975800E+00 -2.2638000E-01 -3.8946600E+00 -2.0974500E-01   DR11CMASS
# DR11LyaAuto_like   -2.3858700E+00 -2.8878700E+00 -2.0867700E+00 -2.9641900E+00 -2.0053600E+00   DR11LyaAuto
# DR11LyaCross_like  -2.0558800E+00 -2.3552800E+00 -1.8428600E+00 -2.4674400E+00 -1.7538400E+00   DR11LyaCross
# SixdFGS_like       -1.5026800E-01 -7.2983500E-01 -8.9715000E-12 -8.4898800E-01 -8.9715000E-12   SixdFGS
# MGS_like           -2.6368300E-01 -1.5742800E+00 -5.3130900E-07 -1.9046800E+00 -5.3130900E-07   MGS

# %%
g.triangle_plot(['Quintom_phy_Planck_15+BBAO+SN'], ['Om','h','mquin', 'mphan'], 
               # plot_3d_with_param='h', 
                filled=True,
                legend_labels=['Simulation'],
                analysis_settings={'smooth_scale_2D ': -1., 'ignore_rows': 0.2})
g.add_legend(['Planck+BBAO'], 
             colored_text=True,  legend_loc='upper left')  
g.export('Quintom_3d.pdf')

# %%
g.triangle_plot(['Quintom_phy_Planck_15+BBAO+SN'], ['Om','h', 'mquin','mphan'], 
                plot_3d_with_param='h', 
                legend_labels=['Simulation'])
g.add_legend(['Planck+BBAO+SN'],  legend_loc='upper right') 
#g.export('Quintom_3d.pdf')

# %%
dir_name = '/Users/josevazquezgonzalez/Desktop/GM_Sampler/trunk/chains'

# %%
#L=-23.510, 3chains-2300,  ---- L=-23.510, 7G, N500, varcov 
roots = ['LCDM_phy_BBAO+SN+Planck', 'gms_LCDM_phy_BBAO+SN+Planck']
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=12, 
                            analysis_settings={'smooth_scale_1D ': 0.99,  'smooth_scale_2D ': -1,'ignore_rows': 0.0})
#g.triangle_plot(roots, params=['Om', 'h', 'Obh2'])
g.plots_1d(roots, params=['Om', 'h', 'Obh2'], nx=3,legend_labels=False, colors = ['blue','red','green','orange'])
# Out:
# WARNING:root:outlier fraction 0.00031113876789
# /Users/josevazquezgonzalez/Desktop/GM_Sampler/trunk/chains/gms_LCDM_phy_BBAO+SN+Planck_1.txt
# Removed no burn in
# (3, 1)

# %%
#L=-23.353, 3chains-1300, -----L=-23.323, 12G, N500, varcov 
roots = ['wCDM_phy_BBAO+SN+Planck',  'gms_wCDM_phy_BBAO+SN+Planck'] #'gms_fix_owaCDM_phy_BBAO+SN+Planck',
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=12, 
                            analysis_settings={'smooth_scale_1D ': 0.99, 'smooth_scale_2D ': .99, 'ignore_rows': 0.})
#g.triangle_plot(roots, params=['Om', 'h', 'Obh2', 'Ok', 'w', 'wa'])
g.plots_1d(roots, params=['Om', 'h', 'Obh2', 'w'], nx=4, legend_labels=False, colors = ['blue','red','green','orange'])
# Out:
# (4, 1)

# %%
#L=-23.433, 3chains 3400 ------ L-23.3884, 15G, N=200, iblow=500, varcov
roots = ['waCDM_phy_BBAO+SN+Planck',  'gms_waCDM_phy_BBAO+SN+Planck'] #'gms_fix_owaCDM_phy_BBAO+SN+Planck',
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_1D ': 0.99, 'smooth_scale_2D ': .99, 'ignore_rows': 0.2})
#g.triangle_plot(roots, params=['Om', 'h', 'Obh2', 'Ok', 'w', 'wa'])
g.plots_1d(roots, params=['Om', 'h', 'Obh2', 'w', 'wa'], nx=3, legend_labels=False, colors = ['blue','red','green','orange'])
# Out:
# /Users/josevazquezgonzalez/Desktop/GM_Sampler/trunk/chains/waCDM_phy_BBAO+SN+Planck_1.txt
# /Users/josevazquezgonzalez/Desktop/GM_Sampler/trunk/chains/waCDM_phy_BBAO+SN+Planck_2.txt
# /Users/josevazquezgonzalez/Desktop/GM_Sampler/trunk/chains/waCDM_phy_BBAO+SN+Planck_3.txt
# WARNING:root:outlier fraction 0.000433526011561
# Removed 0.2 as burn in
# (3, 2)

# %%
dir_name = '/Users/josevazquezgonzalez/Desktop/chains_no_git'

# %%
roots = ['LCDM_phy_SN_nested_dynesty_multi', 
        'LCDM_phy_HD_nested_dynesty_multi', 
        'LCDM_phy_CBAO_nested_dynesty_multi']
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=12, 
                            analysis_settings={'smooth_scale_1D ': 0.99,  'smooth_scale_2D ': -1,'ignore_rows': 0.0})
g.plots_1d(roots, params=['Om', 'h', 'Obh2'], nx=3,legend_labels=False, colors = ['blue','red','green','orange'])
# Out:
# /Users/josevazquezgonzalez/Desktop/chains_no_git/LCDM_phy_SN_nested_dynesty_multi_1.txt
# Removed no burn in
# /Users/josevazquezgonzalez/Desktop/chains_no_git/LCDM_phy_HD_nested_dynesty_multi_1.txt
# Removed no burn in
# /Users/josevazquezgonzalez/Desktop/chains_no_git/LCDM_phy_CBAO_nested_dynesty_multi_1.txt
# Removed no burn in
# (3, 1)

# %%
for root in roots:
    samples = g.sampleAnalyser.samplesForRoot(root)
    print samples.likeStats
# Out:
# Best fit sample -log(Like) = 16.607197
# mean(-Ln(like)) = 17.620078
# -Ln(mean like)  = 17.284598
#
# parameter        bestfit        lower1         upper1         lower2         upper2
# Om               2.9623737E-01  2.4839079E-01  3.4888838E-01  2.1959167E-01  3.8317654E-01   \Omega_m
# Obh2             2.2019960E-02  2.1379850E-02  2.2693180E-02  2.0895570E-02  2.3124840E-02   \Omega_{b}h^2
# h                8.1201977E-01  4.0004298E-01  8.9952255E-01  4.0004298E-01  8.9952255E-01   h
# BetouleSN_like  -1.6607214E+01 -1.7712910E+01 -1.6607002E+01 -1.9728079E+01 -1.6607002E+01   BetouleSN
# theory_prior    -2.1413957E-05 -1.0708289E+00 -1.4084753E-08 -2.9875961E+00 -1.4084753E-08   None
#
# Best fit sample -log(Like) = 7.250689
# mean(-Ln(like)) = 8.675089
# -Ln(mean like)  = 8.249969
#
# parameter      bestfit        lower1         upper1         lower2         upper2
# Om             3.2065133E-01  2.3497790E-01  4.5075782E-01  1.9530001E-01  4.9509685E-01   \Omega_m
# Obh2           2.2011870E-02  2.1296520E-02  2.2768840E-02  2.0843250E-02  2.3201430E-02   \Omega_{b}h^2
# h              6.8159793E-01  6.0585876E-01  7.5153822E-01  5.7098997E-01  7.9588675E-01   h
# HD_like       -7.2505907E+00 -8.7772894E+00 -7.2502926E+00 -1.0969689E+01 -7.2502926E+00   HD
# theory_prior  -2.5527721E-03 -1.3250428E+00 -1.9083732E-07 -3.2981695E+00 -1.9083732E-07   None
#
# Best fit sample -log(Like) = 5.551117
# mean(-Ln(like)) = 7.313784
# -Ln(mean like)  = 6.743124
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0770397E-01  2.7988589E-01  3.4059831E-01  2.6261285E-01  3.5607017E-01   \Omega_m
# Obh2                2.2006790E-02  2.1127860E-02  2.2892490E-02  2.0855810E-02  2.3286750E-02   \Omega_{b}h^2
# h                   6.8379708E-01  6.6079047E-01  6.9707822E-01  6.4614973E-01  7.0200555E-01   h
# BAODR12_like       -1.5386152E+00 -3.0919319E+00 -1.3020836E+00 -5.2176433E+00 -1.2576900E+00   BAODR12
# DR14LyaAuto_like   -8.4958356E-01 -1.7469455E+00 -4.5050739E-01 -2.3082255E+00 -3.5658026E-01   DR14LyaAuto
# DR14LyaCross_like  -2.1376564E+00 -3.0843259E+00 -1.5447275E+00 -3.6342256E+00 -1.3116488E+00   DR14LyaCross
# SixdFGS_like       -1.4323927E-03 -1.2344834E-01 -5.7969190E-10 -2.3224767E-01 -5.7969190E-10   SixdFGS
# MGS_like           -9.5877372E-01 -1.8076947E+00 -2.4565648E-01 -2.3666594E+00 -8.3955874E-02   MGS
# eBOSS_like         -6.3622036E-02 -2.0000000E+00 -1.9772735E-06 -2.0000000E+00 -1.9772735E-06   eBOSS
# theory_prior       -3.6266205E-03 -1.8807082E+00 -1.6491825E-07 -3.7917212E+00 -1.6491825E-07   None

# %%
roots = ['Quintess_phy_SN_nested_dynesty_multi', 'Quintess_phy_HD_nested_dynesty_multi', 
         'Quintess_phy_CBAO_nested_dynesty_multi']

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=7, 
                            analysis_settings={'smooth_scale_2D': -1, 'smooth_scale_1D': -1, 'ignore_rows': 0.0})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['SN', 'HD', 'BAO'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')
g.subplots[1,0].grid(True)
g.subplots[1,0].set_ylim(0, 2.1)

g.subplots[1,1].set_xlim(0, 2.1)

g.subplots[0,0].set_title('Quintessence', fontsize=20)
# Out:
# /Users/josevazquezgonzalez/Desktop/chains_no_git/Quintess_phy_SN_nested_dynesty_multi_1.txt
# Removed no burn in
# /Users/josevazquezgonzalez/Desktop/chains_no_git/Quintess_phy_HD_nested_dynesty_multi_1.txt
# Removed no burn in
# /Users/josevazquezgonzalez/Desktop/chains_no_git/Quintess_phy_CBAO_nested_dynesty_multi_1.txt
# Removed no burn in
# Text(0.5,1,'Quintessence')

# %%
#for root in roots:
#    samples = g.sampleAnalyser.samplesForRoot(root)
#    print samples.likeStats

# %%
roots = ['Phantom_phy_SN_nested_dynesty_multi',
         'Phantom_phy_HD_nested_dynesty_multi', 
         'Phantom_phy_CBAO_nested_dynesty_multi',  
         ]  

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=7, 
                            analysis_settings={'smooth_scale_2D': -1, 'smooth_scale_1D': -1, 'ignore_rows': 0.0})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mphan'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['SN', 'HD', 'BAO'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')
g.subplots[1,0].grid(True)
g.subplots[1,0].set_ylim(0, 2.8)

g.subplots[1,1].set_xlim(0, 2.8)

g.subplots[0,0].set_title('Phantom', fontsize=20)
# Out:
# /Users/josevazquezgonzalez/Desktop/chains_no_git/Phantom_phy_SN_nested_dynesty_multi_1.txt
# Removed no burn in
# /Users/josevazquezgonzalez/Desktop/chains_no_git/Phantom_phy_HD_nested_dynesty_multi_1.txt
# Removed no burn in
# /Users/josevazquezgonzalez/Desktop/chains_no_git/Phantom_phy_CBAO_nested_dynesty_multi_1.txt
# Removed no burn in
# Text(0.5,1,'Phantom')

# %%
#for root in roots:
#    samples = g.sampleAnalyser.samplesForRoot(root)
#    print samples.likeStats

# %%
roots = ['Quintom_phy_SN_nested_dynesty_multi',
         'Quintom_phy_HD_nested_dynesty_multi',
         'Quintom_phy_CBAO_nested_dynesty_multi'
        ] #, 'Quintom_phy_BBAO+HD',  'Quintom_phy_BBAO+Planck_15+HD']

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=8, 
                            analysis_settings={'smooth_scale_2D': -1, 'smooth_scale_1D': -1, 'ignore_rows': 0.0})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['SN', 'HD', 'BAO'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')

g.subplots[1,0].set_ylim(0, 3.6)
g.subplots[2,0].set_ylim(0, 3.)
g.subplots[1,1].set_xlim(0, 3.6)
g.subplots[2,1].set_xlim(0, 3.6)
g.subplots[2,1].set_ylim(0, 3.)
g.subplots[2,2].set_xlim(0, 3.)

g.subplots[1,0].grid(True)
g.subplots[2,0].grid(True)
g.subplots[2,1].grid(True)

g.subplots[0,0].set_title('Quintom', fontsize=20)
# Out:
# /Users/josevazquezgonzalez/Desktop/chains_no_git/Quintom_phy_SN_nested_dynesty_multi_1.txt
# Removed no burn in
# /Users/josevazquezgonzalez/Desktop/chains_no_git/Quintom_phy_HD_nested_dynesty_multi_1.txt
# Removed no burn in
# /Users/josevazquezgonzalez/Desktop/chains_no_git/Quintom_phy_CBAO_nested_dynesty_multi_1.txt
# Removed no burn in
# Text(0.5,1,'Quintom')

# %%
#for root in roots:
#    samples = g.sampleAnalyser.samplesForRoot(root)
#    print samples.likeStats

# %%
roots = ['Quintom_couple_phy_SN_nested_dynesty_multi',
         'Quintom_couple_phy_HD_nested_dynesty_multi',
         'Quintom_couple_phy_CBAO_nested_dynesty_multi'
        ]

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=9, 
                            analysis_settings={'smooth_scale_2D': -1, 'smooth_scale_1D': -1, 'ignore_rows': 0.0})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan', 'beta'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['SN', 'HD', 'BAO'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')
g.subplots[1,0].set_ylim(0, 4.6)
g.subplots[1,1].set_xlim(0, 4.8)
g.subplots[2,0].set_ylim(0, 4.)
g.subplots[2,1].set_xlim(0, 4.8)
g.subplots[2,1].set_ylim(0, 4.)
g.subplots[2,2].set_xlim(0, 4.)
g.subplots[3,0].set_ylim(-15, 15.)
g.subplots[3,1].set_xlim(0, 4.8)
g.subplots[3,1].set_ylim(-15, 15)
g.subplots[3,2].set_xlim(0, 4.)
g.subplots[3,2].set_ylim(-15, 15.)
g.subplots[3,3].set_xlim(-15, 15.)

g.subplots[1,0].grid(True)
g.subplots[2,0].grid(True)
g.subplots[2,1].grid(True)
g.subplots[3,0].grid(True)
g.subplots[3,1].grid(True)
g.subplots[3,2].grid(True)

g.subplots[0,0].set_title('Quintom + $\\beta$', fontsize=20)
#g.export('Quintom_coupling.pdf')
# Out:
# /Users/josevazquezgonzalez/Desktop/chains_no_git/Quintom_couple_phy_SN_nested_dynesty_multi_1.txt
# Removed no burn in
# /Users/josevazquezgonzalez/Desktop/chains_no_git/Quintom_couple_phy_HD_nested_dynesty_multi_1.txt
# Removed no burn in
# /Users/josevazquezgonzalez/Desktop/chains_no_git/Quintom_couple_phy_CBAO_nested_dynesty_multi_1.txt
# Removed no burn in
# Text(0.5,1,'Quintom + $\\beta$')

# %%
#for root in roots:
#    samples = g.sampleAnalyser.samplesForRoot(root)
#    print samples.likeStats

# %%
roots = ['Quintess_phy_CBAO_nested_dynesty_multi',  'Phantom_phy_CBAO_nested_dynesty_multi',
        'Quintom_phy_CBAO_nested_dynesty_multi']
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_1D ': 0.99, 'smooth_scale_2D ': .99, 'ignore_rows': 0.1})
g.plots_1d(roots, params=['DR14LyaAuto_like', 'DR14LyaCross_like', 'BAODR12_like'], nx=3,legend_labels=False, colors = ['blue','red','green','orange'])
# Out:
# /Users/josevazquezgonzalez/Desktop/chains_no_git/Quintess_phy_CBAO_nested_dynesty_multi_1.txt
# Removed 0.1 as burn in
# /Users/josevazquezgonzalez/Desktop/chains_no_git/Phantom_phy_CBAO_nested_dynesty_multi_1.txt
# Removed 0.1 as burn in
# /Users/josevazquezgonzalez/Desktop/chains_no_git/Quintom_phy_CBAO_nested_dynesty_multi_1.txt
# Removed 0.1 as burn in
# (3, 1)
