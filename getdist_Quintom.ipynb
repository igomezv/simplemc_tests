# %%
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
from getdist import *

# import planckStyle
import pylab
import numpy as np
import matplotlib
import tkinter

matplotlib.use('TkAgg')


# %matplotlib inline

# %%
# dir_name = '/home/cosmocicatais/simpleMC/chains/'
dir_name = '/home/isidro/Documents/gitHub/simplemc_tests/simplemc/chains/'
# dir_name = "chains/"


roots_couple = [
                'Quintom_couple_phy_HD_nested_multi',
                'Quintom_couple_phy_CBAO_nested_multi',
                ]

roots_quintom = [
                 'Quintom_phy_HD_nested_multi',
                 ]


roots_all = [
                'Quintom_phy_HD_nested_multi',
                'Quintom_couple_phy_HD_nested_multi',
                'Quintom_couple_phy_CBAO_nested_multi',
                
           ]

# %%
g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.9, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

# %% [markdown]
# ### Triangle plot Phantom with coupling

# %%
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 15
g.settings.axes_fontsize = 15   
# g.settings.lw1 = 0.5

g.triangle_plot(roots_couple, ['Om', 'Obh2', 'h', 'mquin', 'mphan', 'beta'],
# g.triangle_plot(roots, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
#                 alphas = [1.0, 0.7, 0.5],
                legend_labels=['Quintom with coupling HD', 'Quintom with coupling CBAO'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)
        
#plt.show()
plt.savefig('TriangleQuintomCouple.png', dpi=80)

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 15
gg.settings.axes_fontsize = 25 

# plt.figure(figsize=(10,8))
gg.plot_2d(roots_couple, 'h', 'beta', colors=['black', 'red'], 
          filled=True, alphas = [0.8, 0.7, 0.6], 
          legend_loc='upper right')

gg.add_legend(['Quintom with coupling HD',
                               'Quintom with coupling CBAO'])
plt.savefig('hvsbeta_QuintomCouple.png', dpi=80)

# %% [markdown]
# ### ALL

# %%
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 15
g.settings.axes_fontsize = 15   
# g.settings.lw1 = 0.5

g.triangle_plot(roots_all, ['Om', 'Obh2', 'h', 'mquin', 'mphan'],
# g.triangle_plot(roots, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue', 'yellow'],
#                 alphas = [1.0, 0.7, 0.5],
                legend_labels=['Quintom HD', 'Quintom with coupling HD',
                               'Quintom with coupling CBAO'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)
        
#plt.show()
plt.savefig('TriangleQuintomAll.png', dpi=80)

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 15
gg.settings.axes_fontsize = 25 

# plt.figure(figsize=(10,8))
gg.plot_2d(roots_all, 'mquin', 'mphan', colors=['black', 'red'], 
          filled=True, alphas = [0.8, 0.7, 0.6], 
          legend_loc='upper right')

gg.add_legend(['Quintom HD', 'Quintom with coupling HD',
                               'Quintom with coupling CBAO'])

# gg.add_x_marker(-1, color='green', lw=3.0)
# gg.add_y_marker(0, color='green', lw=3.0)
# plt.ylim(-3.1,3.1)
# plt.xlim(-2.5,0.5)
# plt.text(-2.2, -2.7, 'Datasets: CC', fontsize=25)
# plt.text(-2.2, -2.2, 'CPL', fontsize=25)

plt.savefig('phivspsi_Quintom.png', dpi=80)
